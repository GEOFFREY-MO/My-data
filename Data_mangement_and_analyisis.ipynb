# %% [markdown]
# <a href="https://colab.research.google.com/github/GEOFFREY-MO/My-data/blob/main/Data_mangement_and_analyisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Code: TM351-Data Management and
# Analysis**

# %% [markdown]
# **Question 1 (30 marks)**
#
# **2.2.1 Data file formats -CSV**
#
# File Description
#
# File Name: Titanic Dataset
#
# Type: csv file
#
# Size: 61.19 kB
#
# Link: https://www.kaggle.com/datasets/yasserh/titanic-dataset

# %% [markdown]
# **2.2.2 Data file formats – JSON**
#
# File Description
#
# File Name: ISO_code
#
# Type: json file
#
# Size: 83KB
#
# Link:https://www.kaggle.com/datasets/rtatman/stopword-lists-for-african-languages/download?datasetVersionNumber=1

# %% [markdown]
# **3.4 Handling missing data**

# %%
#importig the necesary library
import pandas as pd
#upload the dataset
data = pd.read_csv('Titanic-Dataset.csv')
#display the first five rows
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#check whether there is null values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Handling the missing value by filling using mean manupulation

# %%
#Fill in missing values with mean imputation
data['Age'].fillna(data['Age'].mean(), inplace=True)
print(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# **4.1 Crosstabs and pivot tables**
#
# **Crosstabs** Summarizes the relationship between two or more categorical variables also, they are Easy to create and interpret, computationally efficient. While Pivot tables plays avery important role of Summarizing and analyzing data from multiple variables as well as it's Versatile, can handle complex relationships between variables, can calculate complex statistics.
#
# Here is the code of how to implement it.

# %%
# Create a crosstab of 'PassengerId' and 'Survived'
crosstab_passenger_id_survived = pd.crosstab(data['PassengerId'], data['Survived'])
print("Crosstab of PassengerId and Survived:")
print(crosstab_passenger_id_survived)

# Create a crosstab of 'Pclass' and 'Embarked'
crosstab_pclass_embarked = pd.crosstab(data['Pclass'], data['Embarked'])
print("Crosstab of Pclass and Embarked:")
print(crosstab_pclass_embarked)

# Create a crosstab of 'Sex' and 'Parch'
crosstab_sex_parch = pd.crosstab(data['Sex'], data['Parch'])
print("Crosstab of Sex and Parch:")
print(crosstab_sex_parch)

# Create a pivot table to summarize the relationship between 'Age', 'Pclass', and 'Fare'
pivot_table_age_pclass_fare = data.pivot_table(index='Age', columns='Pclass', values='Fare', aggfunc='mean')
print("Pivot table summarizing Age, Pclass, and Fare:")
print(pivot_table_age_pclass_fare)

# Create a crosstab of 'Age' and 'Pclass'
crosstab_age_pclass = data.pivot_table(index='Age', columns='Pclass', values='Fare', aggfunc='mean')
# Print the crosstabs
print(crosstab_age_pclass)
# Out:
# Crosstab of PassengerId and Survived:
# Survived     0  1
# PassengerId
# 1            1  0
# 2            0  1
# 3            0  1
# 4            0  1
# 5            1  0
# ...         .. ..
# 887          1  0
# 888          0  1
# 889          1  0
# 890          0  1
# 891          1  0
#
# [891 rows x 2 columns]
# Crosstab of Pclass and Embarked:
# Embarked   C   Q    S
# Pclass
# 1         85   2  127
# 2         17   3  164
# 3         66  72  353
# Crosstab of Sex and Parch:
# Parch     0   1   2  3  4  5  6
# Sex
# female  194  60  49  4  2  4  1
# male    484  58  31  1  2  1  0
# Pivot table summarizing Age, Pclass, and Fare:
# Pclass         1       2        3
# Age
# 0.42         NaN     NaN   8.5167
# 0.67         NaN  14.500      NaN
# 0.75         NaN     NaN  19.2583
# 0.83         NaN  23.875      NaN
# 0.92    151.5500     NaN      NaN
# ...          ...     ...      ...
# 70.00    71.0000  10.500      NaN
# 70.50        NaN     NaN   7.7500
# ...

# %% [markdown]
# **4.2 Descriptive statistics in pandas**

# %%
#describe the data
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #**4.4 Walkthrough**
#
# Walkthrough involves a structure that conducts data analysis, data collection, data preparation, exploration, modeling, interpretation, and finally communication. (*Story telling*)
#
# ##**Step 1: Defining the problem and objective**
#
# Clearly define the question data analysis aims to address. Ones the problem is defined, establish a goal describing what the analysis seeks to achieve.
#
# ##**Step 2: Collect and Prepare data**
#
# Data collection is the another ensential part that should be used to answer the questions from the insights in it. A well prepared data gives clear rsults and it avoid alot of noisy and anormalies. The pre-processed data should be suitable for the choosen analysis.
#
# ##**Step 3: Exploratory Data Analysis**
#
# This stage enables the analyst or scientist to understand better the data by obseving the characteristics, patterns and trends within the data.
# This in general summarizes the data.
# Also, necessary visualizations are employed to visualize the distribution of variables and relationship between them.
#
# ##**Step 4: Data Modeling and Analysis**
# After gaining insights from the Exploratory data analysis. Modeling is approriate. Choosen technique should be used depending on the nature of the data desired outcome. For instance clustering, regression analysis, statistical methods and machine learning algorithms.
#
# ##**Step 5: Interpretation and communication of the results.**
# Effective communication is required in explainations, visualizations and supporting evidence.
#
# ##**Step 6: Evaluation and Iteration**
# Data anlysis process is iterative, requires continuous evaluation and refinement. This creates good customer feedbacks and ratings.

# %% [markdown]
# ##**4.6 Introducing regular expressions**
#
#
#
# * Cleaning and pre-processing text data: Regular expressions can be used to remove HTML tags, punctuation, and other unwanted characters from text data.
#
# * Extracting information from text data: Regular expressions can be used to extract specific information from text data, such as email addresses, phone numbers, and URLs.
#
# * Validating data: Regular expressions can be used to validate data, such as ensuring that phone numbers have the correct format and that email addresses are well-formed.
#
# * Transforming text data into a format suitable for analysis: Regular expressions can be used to transform text data into a format suitable for analysis, such as tokenizing text into individual words
#
#
#
#
#
# ---

# %% [markdown]
# #**example of regular expression in python code**

# %%
#import regular expresion library
import re

# Define the regular expression pattern
pattern = r"\d{3}-\d{3}-\d{4}"

# Extract phone numbers from text
text = "My phone number is 555-555-5555. Please call me at 123-456-7890."
matches = re.findall(pattern, text)

# Print the extracted phone numbers
print(matches)
# Out:
# ['555-555-5555', '123-456-7890']

# %%
# Define the regular expression pattern
pattern = r"<.*?>"

# Remove HTML tags from text
text = "<p>This is some text with HTML tags.</p>"
clean_text = re.sub(pattern, "", text)

# Print the clean text
print(clean_text)
# Out:
# This is some text with HTML tags.

# %% [markdown]
# ##**4.7 Reshaping data with pandas**

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=list('ABC'))
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# We can try to reshape the data let say to three rows and 3 columns by using reshape() function from pandas libraly.

# %%
# Reshape the DataFrame to have 3 rows and 3 columns
reshaped_df = df.to_numpy().reshape(3, 3)
print(reshaped_df)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %% [markdown]
# Lets try to reshape our data frame to 1 column

# %%
# Reshape the DataFrame to have 9 rows and 1 column
reshaped_df = df.to_numpy().reshape(-1, 1)
print(reshaped_df)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]
#  [7]
#  [8]
#  [9]]

# %% [markdown]
# Now as you can see it's really easy to manupulate the
#
# data
# frame the way you need it to be presented by using a simple
#
# lines of codes.

# %% [markdown]
# **--- show at least three screenshots from OpenRefine**
#
# **Column edit in openrefine**
#
# ![column edit.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Delete row**
#
#
# ![delete row.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Removing column**
#
# ![removing column.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ##**5.1 Anscombe’s Quartet - visualising data**

# %%
#import library
import matplotlib.pyplot as plt
import numpy as np
# Load the data
data = pd.read_csv("anscombe.csv")

# Calculate the number of rows needed for subplots
num_rows = (data.shape[0] + 1) // 2
# Create histograms
fig, axs = plt.subplots(num_rows, 2, figsize=(10, 10))

# Iterate through rows of data and plot on existing subplots
for i, row in data.iterrows():
    row_index = i // 2
    col_index = i % 2
    if row_index < num_rows:
        axs[row_index, col_index].hist(row[1:])

# Label axes and show plot
plt.xlabel("X")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Let us go a head to visualize the anscombe data using boxplot

# %%
# Calculate the number of rows needed for subplots
num_rows = (data.shape[0] + 1) // 2

# Create box plots
fig, axs = plt.subplots(num_rows, 2, figsize=(10, 10))

# Iterate through rows of data and plot box plots on existing subplots
for i, row in data.iterrows():
    row_index = i // 2
    col_index = i % 2
    if row_index < num_rows:
          #plot the boxplot
        axs[row_index, col_index].boxplot(row[1:], vert=False)

# Label axes and show plot
plt.xlabel("X")
plt.ylabel("Value")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Scatter plots for the data.

# %%
# Calculate the number of rows needed for subplots
num_rows = (data.shape[0] + 1) // 2

# Create scatter plots
fig, axs = plt.subplots(num_rows, 2, figsize=(10, 10))
# Iterate through rows of data and plot scatter plots on existing subplots
for i, row in data.iterrows():
    row_index = i // 2
    col_index = i % 2
    if row_index < num_rows:
        axs[row_index, col_index].scatter(range(1, len(row)), row[1:])

# Label axes and show plot
plt.xlabel("X")
plt.ylabel("Y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## This line plot shows clearly how the data is behaving and its relationship.

# %%
# Create scatter plots with line graphs
fig, axs = plt.subplots(num_rows, 2, figsize=(10, 10))

# Iterate through rows of data and plot scatter plots and line graphs on existing subplots
for i, row in data.iterrows():
    row_index = i // 2
    col_index = i % 2
    if row_index < num_rows:
        x_values = range(1, len(row))
        axs[row_index, col_index].scatter(x_values, row[1:], alpha=0.5, label='Scatter')
        axs[row_index, col_index].plot(x_values, row[1:], color='red', label='Line')

# Label axes and show plot
plt.xlabel("X")
plt.ylabel("Y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##**5.2 Getting started with maps – folium**

# %% [markdown]
# **Installation of the folium library**

# %%
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# In this step we create a sample map by  puting the coordinate of the city in Saudi Arabia.

# %%
# Create a map centered at a specific location
latitude = 	24.6667
longitude = 46.6958
simple_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# Display the map
simple_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **Let now customize the map**

# %%
# Customize the map by changing the tileset
customized_map = folium.Map(location=[latitude, longitude], zoom_start=12, tiles='Stamen Terrain')

# Display the customized map
customized_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **Add makers to the map**
#
# This step is associated with a location (latitude, longitude) and a popup message.

# %%
# Create a map with markers
marker_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# Add markers to the map
folium.Marker([latitude + 0.01, longitude], popup='Marker 1').add_to(marker_map)
folium.Marker([latitude, longitude + 0.01], popup='Marker 2').add_to(marker_map)

# Display the map with markers
marker_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **Creating a Heatmap**
#
# This code is capable of generating random data and creates a heatmap layer on the map using the HeatMap plugin from Folium libraly.

# %%
# Generate random data for a heatmap
heat_data = [[latitude + 0.001, longitude + 0.001, 1],
             [latitude - 0.002, longitude - 0.002, 2],
             [latitude + 0.003, longitude - 0.001, 3]]

# Create a map with a heatmap layer
heatmap_map = folium.Map(location=[latitude, longitude], zoom_start=12)
folium.plugins.HeatMap(heat_data).add_to(heatmap_map)

# Display the map with the heatmap layer
heatmap_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# **Next step is Combine Marker and Heatmap**
#
#  Here, we combine both markers and a heatmap layer on the same map.

# %%
# Create a map with both markers and a heatmap
combined_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# Add markers to the map
folium.Marker([latitude + 0.01, longitude], popup='Marker 1').add_to(combined_map)
folium.Marker([latitude, longitude + 0.01], popup='Marker 2').add_to(combined_map)

# Add a heatmap layer to the map
folium.plugins.HeatMap(heat_data).add_to(combined_map)

# Display the map with markers and heatmap
combined_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ##**8.1 Movies dataset**
#
# Let's Now work with movie data.

# %%
#import libraly for visualization
import seaborn as sns

# %%
#Loading the dataset
movies_df = pd.read_csv('imdb_movies.csv')

# Display the first few rows of the dataset
movies_df.head()
# Out:
#                          names       date_x  score  \
# 0                    Creed III  03/02/2023    73.0
# 1     Avatar: The Way of Water  12/15/2022    78.0
# 2  The Super Mario Bros. Movie  04/05/2023    76.0
# 3                      Mummies  01/05/2023    70.0
# 4                    Supercell  03/17/2023    61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
# ...

# %% [markdown]
# **Data exploration**

# %%
#checking the statistics in the dataset
summary_stats = movies_df.describe()

# Get information about the dataset, such as data types and missing values
data_info = movies_df.info()

# Explore unique values in a specific column let say the 'genre'
unique_genres = movies_df['genre'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       10178 non-null  object
#  1   date_x      10178 non-null  object
#  2   score       10178 non-null  float64
#  3   genre       10093 non-null  object
#  4   overview    10178 non-null  object
#  5   crew        10122 non-null  object
#  6   orig_title  10178 non-null  object
#  7   status      10178 non-null  object
#  8   orig_lang   10178 non-null  object
#  9   budget_x    10178 non-null  float64
#  10  revenue     10178 non-null  float64
#  11  country     10178 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 954.3+ KB

# %% [markdown]
# **Data visualization**
#
# This focuses on the genre column and the number of movies

# %%
# Plot a bar chart of movie genres
plt.figure(figsize=(10, 8))
sns.countplot(x='genre', data=movies_df, order=movies_df['genre'].value_counts().index)
plt.title('Number of Movies by Genre')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# As you can observe the above graph the genre movies compared with the number of movies it seems to be higher.

# %% [markdown]
# **Analyzing the relationship**

# %%
# Create a scatter plot to analyze the relationship between 'budget_x' and 'revenue'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='budget_x', y='revenue', data=movies_df)
plt.title('Relationship between Budget and Revenue')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# **Conduct Analysis**

# %%
# Calculate the average revenue for each genre
avg_revenue_by_genre = movies_df.groupby('genre')['revenue'].mean().sort_values(ascending=False)

# Display the result
print("Average Revenue by Genre:\n", avg_revenue_by_genre)
# Out:
# Average Revenue by Genre:
#  genre
# Adventure, Action, Science Fiction, Fantasy                                               2.068224e+09
# Family, Animation, Adventure, Comedy, Fantasy                                             1.437863e+09
# Family, Animation, Drama                                                                  1.316964e+09
# Animation, Action, Comedy, Mystery, Crime, Fantasy                                        1.213426e+09
# TV Movie, Animation, Science Fiction, Action, Adventure, Comedy, Drama, Fantasy, Music    1.180869e+09
#                                                                                               ...
# Action, Thriller, Crime, Adventure                                                        0.000000e+00
# Crime, Fantasy, Horror, Thriller                                                          0.000000e+00
# Action, Crime, Horror, Thriller                                                           0.000000e+00
# ...

# %% [markdown]
# From the above results you can clearly see that the revenue  for the Adventure, Action, Science Fiction, Fantasy is extreamly high of about 2.068224e+09 when compare to the other genre.

# %% [markdown]
# ##**QUESTION 2**
#
# We conducted pandas profiling so that we can understand better the dataset and answer the questions.
