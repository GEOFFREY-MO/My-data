# %% [markdown]
# <a href="https://colab.research.google.com/github/GEOFFREY-MO/My-data/blob/main/python_for_everyone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CHAPTER 1 EXERCISES**

# %% [markdown]
# **Exercise 1:**
#
# What is the function of the secondary memory in a computer?
#
# Ans: *Store information for long term, even beyond a power cycle*
#
# **Exercise 2:**
#
# What is a program?
#
# Ans: *Is a python language that is written to converse with a computer to solve a problem*
#
# **Exercise 3:**
#
# What is the difference beween a compiler and interpreter?
#
# Ans: *A compiler is device used to translate a program written in high-level language into a low-level language all at once, in prepapration for execution later on while Interpreter is a device used in executing a program in ahigh-level language by translating it one line at a time.*
#
# **Exercise 4:**
#
# WHich of the following contans "machine code"?
#
# Ans: *Python source file*
#
# **Exercise 5:**
#
# What is wrong with the following code:
#
# ![image.png](data:image/png;base64,...)
#
# Ans: *There is the violetion of the reserved word "***primt***" instead of "***print***"*
#
# **Exercise 6:**
#
# Where in the computer is a variable such as "x" stored after the following Python line finishes?
#
# ![image.png](data:image/png;base64,...)
#
# Ans: *Main memory*
#
# **Exercise 7:**
#
# What will the following program print out:
#
# ![image.png](data:image/png;base64,...)
#
# Ans: *42*
#
# **Exercise 8:**
#
# Explain each of the following using an example of a human capability: (1) Central Processing Unit, (2) Main Memory, (3) Secondary Memory, (4) Input Device,For example, "What is the human equivalent to Central Processing Unit"?
#
#
#
#
#
# **Exercise 9:**
#
# How do you fix a "Syntax Error"?
#
# Ans: *By debugging*

# %% [markdown]
# **CHAPTER 2 EXERCISES**

# %% [markdown]
# **Exercise 2:**
#
# Write a program that uses input to prompt a user for their nameand then welcomes them.
#
# ![image.png](data:image/png;base64,...)

# %%
name = input('Enter your name: ')
print('Hello',name)
# Out:
# Enter your name: Chuck
# Hello Chuck

# %% [markdown]
# **Exercise 3:**
#
# White a program to prompt the user for hours and rate per hour to compute gross pay.
#
# ![image.png](data:image/png;base64,...)

# %%
Hours = int(input("Enter Hours: "))
Rate = float(input("Enter Rate: "))

pay = (Hours*Rate)
print('Pay: ',pay)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay:  96.25

# %% [markdown]
# **Exercise 5:**
#
# Write a program which prompts the user for a Celsius temperature, convert the tempreture to Fahrenheit, and print out the converted temperature.

# %%
Temp = float(input('Enter temperature in Celsius: '))
Fah  = (Temp*9/5) + 32
print('Temperature in Fahrenheit: ',Fah)
# Out:
# Enter temperature in Celsius: 37
# Temperature in Fahrenheit:  98.6

# %% [markdown]
# **CHAPTER 3:**
#
# **3.11   Exercises**
#
# **Exercise 1:**
# Rewrite your pay computation to give the employee 1.5 times the hourly rate for hours worked above 40 hours.

# %%
Hours = float(input('Enter Hours: '))
Rate = float(input('Enter Rate: '))
if Hours > 40:
  pay = Hours*1.5*Rate
else:
  pay = Hours*Rate
print('Pay: ',pay)
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Pay:  675.0

# %% [markdown]
# **Exercise 2:** Rewrite your pay program using try and except so that your program handles non-numeric input gracefully by printing a message and exiting the program. The following shows two executions of the program:
#
# ![image.png](data:image/png;base64,...)

# %%
Hours = input("Enter Hours: ")
Rate = input("Enter Rate: ")
try:
  pay = Hours*Rate
  print('Pay: ',pay)
except:
  print('Error, Please enter numeric input')
# Out:
# Enter Hours: 45
# Enter Rate: 10
# Error, Please enter numeric input

# %% [markdown]
# **Exercise 3:** Write a program to prompt for a score between 0.0 and 1.0. If the score is out of range, print an error message. If the score is between 0.0and 1.0, print a grade using the following table:
#
# ![image.png](data:image/png;base64,...)

# %%
try:
    score = input("Enter score: ")
    score = float(score)

    if score < 0.0 or score > 1.0:
        print("Bad score")
    else:
        if score >= 0.9:
            print("A")
        elif score >= 0.8:
            print("B")
        elif score >= 0.7:
            print("C")
        elif score >= 0.6:
            print("D")
        else:
            print("F")
except ValueError:
    print("Bad score")
# Out:
# Enter score: PERFECT
# Bad score
